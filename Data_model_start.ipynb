# %%
#Initial Setup
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dass.csv')
df.head()
# Out:
#   country  education  urban  gender  engnat age_group  hand  religion  \
# 0      IN          2      3       2       2      0-20     1        12
# 1      US          2      3       2       1      0-20     2         7
# 2      PL          2      3       2       2      0-20     1         4
# 3      US          1      3       2       1      0-20     2         4
# 4      MY          3      2       2       2      0-20     3        10
#
#    orientation  race  ...       major  Depression  Depression_cat Anxiety  \
# 0            1    10  ...   No Degree          27               3      34
# 1            5    70  ...   No Degree          24               3      17
# 2            3    60  ...   No Degree          39               4      12
# 3            5    70  ...     Biology          16               2      17
# 4            1    10  ...  Psychology          32               4      40
#
#    Anxiety_cat  Stress  Stress_cat            dep_cond            anx_cond  \
# ...

# %%
df['country']=pd.factorize(df['country'], sort=True)[0]+1
df['age_group']=pd.factorize(df['age_group'], sort=True)[0]+1
df['major']=pd.factorize(df['major'], sort=True)[0]+1
df=df.drop(['dep_cond','anx_cond','str_cond'],axis=1)
df.head()
# Out:
#    country  education  urban  gender  engnat  age_group  hand  religion  \
# 0       61          2      3       2       2          1     1        12
# 1      135          2      3       2       1          1     2         7
# 2      105          2      3       2       2          1     1         4
# 3      135          1      3       2       1          1     2         4
# 4       92          3      2       2       2          1     3        10
#
#    orientation  race  voted  married  familysize  major  Depression  \
# 0            1    10      2        1         2.0     46          27
# 1            5    70      2        1         4.0     46          24
# 2            3    60      1        1         3.0     46          39
# 3            5    70      2        1         5.0     10          16
# 4            1    10      2        1         4.0     56          32
#
#    Depression_cat  Anxiety  Anxiety_cat  Stress  Stress_cat
# 0               3       34            4      40           4
# ...

# %%
# Analyze Depression only
X = df.drop(['Depression','Depression_cat','Anxiety','Anxiety_cat','Stress','Stress_cat'],axis=1)
y = df['Stress_cat']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#Standardization-transforming values so mean is 0 and SD is 1
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

knn=KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
y_predict = knn.predict(X_test)
print(knn.score(X_test,y_test))
# Out:
# 0.284012749538668
